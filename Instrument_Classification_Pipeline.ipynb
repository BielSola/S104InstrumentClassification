# %% [markdown]
# # Instrument Classification Pipeline
# This notebook allows you to classify instruments in an audio file using the `run` function from `run_pipeline.py`. You will be prompted to provide the path to your audio file.

# %%
# Import required modules
import run_pipeline

# %%
# Set the path to your audio file here
# Example: audio_path = 'Rama Daya Judave.mp3'
audio_path = 'Rama Daya Judave.mp3'  # <-- Enter your audio file path here

# %%
# Run the instrument classification pipeline
# The results will be displayed as a DataFrame
results = run_pipeline.run(audio_path)
results.head()
# Out:
# Processing chunk 1/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 2/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 3/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 4/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 5/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 6/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 7/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 8/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 9/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 10/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 11/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 12/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 13/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 14/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 15/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 16/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 17/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 18/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 19/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 20/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 21/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 22/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 23/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 24/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 25/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 26/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 27/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 28/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 29/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 30/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 31/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 32/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 33/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 34/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 35/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 36/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 37/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 19/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 20/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 21/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 22/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 23/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 24/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 25/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 26/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 27/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 28/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 29/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 30/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 31/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 32/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 33/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 34/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 35/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 36/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 37/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 38/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 39/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 40/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 41/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 42/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 43/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 44/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 45/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 46/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 47/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 48/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 49/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 50/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 51/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 52/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 53/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 54/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 55/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 56/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 57/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 38/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 39/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 40/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 41/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 42/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 43/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 44/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 45/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 46/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 47/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 48/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 49/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 50/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 51/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 52/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 53/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 54/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 55/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 56/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 57/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 58/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 59/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 60/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 61/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 62/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 63/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 64/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 65/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 66/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 67/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 68/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 69/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 70/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 71/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 72/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 73/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 74/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 75/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 76/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 77/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 58/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 59/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 60/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 61/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 62/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 63/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 64/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 65/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 66/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 67/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 68/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 69/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 70/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 71/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 72/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 73/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 74/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 75/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 76/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 77/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 78/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 79/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 80/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 81/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 82/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 83/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 84/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 85/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 86/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 87/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 88/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 89/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 90/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 91/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 92/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 93/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 94/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 95/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 96/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 97/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 98/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 78/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 79/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 80/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 81/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 82/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 83/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 84/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 85/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 86/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 87/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 88/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 89/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 90/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 91/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 92/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 93/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 94/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 95/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 96/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 97/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 98/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 99/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 100/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 101/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 102/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 103/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 104/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 105/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 106/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 107/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 108/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 109/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 110/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 111/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 112/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 113/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 114/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 115/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 116/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 117/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 99/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 100/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 101/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 102/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 103/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 104/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 105/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 106/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 107/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 108/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 109/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 110/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 111/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 112/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 113/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 114/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 115/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 116/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 117/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 118/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 119/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 120/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 121/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 122/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 123/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 124/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 125/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 126/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 127/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 128/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 129/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 130/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 131/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 132/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 133/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 134/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 135/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 136/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 137/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 138/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 118/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 119/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 120/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 121/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 122/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 123/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 124/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 125/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 126/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 127/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 128/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 129/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 130/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 131/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 132/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 133/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 134/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 135/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 136/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 137/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 138/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 139/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 140/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 141/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 142/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 143/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 144/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 145/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 146/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 147/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 148/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 149/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 150/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 151/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 152/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 153/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 154/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 155/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 156/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 139/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 140/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 141/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 142/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 143/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 144/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 145/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 146/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 147/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 148/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 149/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 150/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 151/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 152/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 153/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 154/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 155/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 156/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 157/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 158/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 159/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 160/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 161/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 162/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 163/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 164/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 165/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 166/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 167/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 168/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 169/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 170/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 171/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 172/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 173/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 174/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 175/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 176/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 177/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 157/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 158/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 159/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 160/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 161/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 162/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 163/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 164/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 165/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 166/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 167/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 168/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 169/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 170/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 171/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 172/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 173/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 174/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 175/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 176/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 177/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 178/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 179/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 180/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 181/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 182/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 183/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 184/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 185/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 186/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 187/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 188/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 189/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 190/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 191/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 192/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 193/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 194/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 195/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 196/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 197/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 178/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 179/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 180/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 181/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 182/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 183/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 184/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 185/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 186/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 187/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 188/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 189/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 190/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 191/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 192/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 193/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 194/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 195/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 196/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 197/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 198/897 for track
# ...
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 854/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 855/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 856/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 857/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 858/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 859/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 860/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 861/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 843/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 844/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 845/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 846/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 847/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 848/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 849/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 850/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 851/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 852/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 853/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 854/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 855/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 856/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 857/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 858/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 859/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 860/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 861/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 862/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 863/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 864/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 865/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 866/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 867/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 868/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 869/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 870/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 871/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 872/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 873/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 874/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 875/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 876/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 877/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 878/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 879/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 862/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 863/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 864/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 865/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 866/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 867/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 868/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 869/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 870/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 871/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 872/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 873/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 874/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 875/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 876/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 877/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 878/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 879/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 880/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 881/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 882/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 883/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 884/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 885/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 886/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 887/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 888/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 889/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 890/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 891/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 892/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 893/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 894/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 895/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 896/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 897/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 880/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 881/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 882/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 883/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 884/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 885/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 886/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 887/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 888/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 889/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 890/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 891/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 892/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 893/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 894/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 895/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 896/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# Processing chunk 897/897 for track
# Compute features for chunk
# Features computed for chunk
# Features dictionary created for chunk
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Run the instrument classification pipeline
#       2 # The results will be displayed as a DataFrame
# ----> 3 results = run_pipeline.run(audio_path)
#       4 results.head()
#
# File c:\Users\solab\OneDrive\Documents\3r_curs\3r_trim\musicology\S104InstrumentClassification\run_pipeline.py:35, in run(audio_path, save_csv_path)
#      33 # Remove columns not used in training
#      34 features_for_model = features.drop(columns=['song', 't1', 't2'], errors='ignore')
# ---> 35 result_violin = violin_model.predict(features_for_model)
#      36 result_voice = vocal_model.predict(features_for_model)
#      37 result_mridangam = mridangam_model.predict(features_for_model)
#
# File c:\Users\solab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_gb.py:1623, in GradientBoostingClassifier.predict(self, X)
#    1608 def predict(self, X):
#    1609     """Predict class for X.
#    1610
#    1611     Parameters
#    (...)   1621         The predicted values.
#    1622     """
# -> 1623     raw_predictions = self.decision_function(X)
#    1624     if raw_predictions.ndim == 1:  # decision_function already squeezed it
#    1625         encoded_classes = (raw_predictions >= 0).astype(int)
#
# File c:\Users\solab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_gb.py:1576, in GradientBoostingClassifier.decision_function(self, X)
#    1557 def decision_function(self, X):
#    1558     """Compute the decision function of ``X``.
#    1559
#    1560     Parameters
#    (...)   1574         array of shape (n_samples,).
#    1575     """
# -> 1576     X = validate_data(
#    1577         self, X, dtype=DTYPE, order="C", accept_sparse="csr", reset=False
#    1578     )
#    1579     raw_predictions = self._raw_predict(X)
#    1580     if raw_predictions.shape[1] == 1:
#
# File c:\Users\solab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2835 def validate_data(
#    2836     _estimator,
#    2837     /,
#    (...)   2843     **check_params,
#    2844 ):
#    2845     """Validate input data and set or check feature names and counts of the input.
#    2846
#    2847     This helper function should be used in an estimator that requires input
#    (...)   2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# File c:\Users\solab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2777, in _check_feature_names(estimator, X, reset)
#    2774 if not missing_names and not unexpected_names:
#    2775     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2777 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - bandwidth
# - spectral_centroid
# - zcr

# %% [markdown]
# ## Saving Results (Optional)
# If you want to save the results to a CSV file, specify the path below and re-run the cell.

# %%
# Save results to CSV (optional)
save_csv_path = ''  # <-- Enter a path like 'results.csv' to save
if save_csv_path:
    results = run_pipeline.run(audio_path, save_csv_path=save_csv_path)
